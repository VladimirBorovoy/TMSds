# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("CarPrice_Assignment.csv")

# %%
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
#df.drop(["car_ID", "CarName"], axis = 1, inplace = True)

# %%
df[df["price"] > 20000]
# Out:
#      car_ID  symboling                          CarName fueltype aspiration  \
# 8         9          1                        audi 4000      gas      turbo
# 12       13          0                           bmw x1      gas        std
# 13       14          0                           bmw x3      gas        std
# 14       15          1                           bmw z4      gas        std
# 15       16          0                           bmw x4      gas        std
# 16       17          0                           bmw x5      gas        std
# 17       18          0                           bmw x3      gas        std
# 47       48          0                        jaguar xj      gas        std
# 48       49          0                        jaguar xf      gas        std
# 49       50          0                        jaguar xk      gas        std
# 67       68         -1         buick electra 225 custom   diesel      turbo
# ...

# %%
sns.displot(data=df, x="carbody", hue="fueltype", 
            multiple="stack", kind='hist')
# Out:
# C:\Users\vboro\.conda\envs\py310\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\vboro\.conda\envs\py310\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\vboro\.conda\envs\py310\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
categories = df[['fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber', 'fuelsystem']]
plt.figure(figsize = (20, 10))
for i, col in enumerate(categories.columns, 1):
  plt.subplot(3, 3, i)
  sns.countplot(x=categories[col], hue=categories[col], palette='pastel')
  plt.tight_layout()
  plt.xticks(rotation=90)
plt.show()

# %%
df["brands"] = df["CarName"].str.split().str[0]
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
df["brands"].value_counts()
# Out:
# brands
# toyota         31
# nissan         17
# mazda          15
# honda          13
# mitsubishi     13
# subaru         12
# peugeot        11
# volvo          11
# volkswagen      9
# dodge           9
# buick           8
# bmw             8
# audi            7
# plymouth        7
# saab            6
# isuzu           4
# porsche         4
# alfa-romero     3
# chevrolet       3
# jaguar          3
# vw              2
# maxda           2
# renault         2
# toyouta         1
# vokswagen       1
# Nissan          1
# mercury         1
# porcshce        1
# Name: count, dtype: int64

# %%
df["brands"] = df["brands"].replace({"maxda": "mazda", "Nissan": "nissan", "vw": "volkswagen", "vokswagen": "volkswagen", "porcshce": "porsche",
                    "toyouta": "toyota"})

# %%
df["brands"].value_counts()
# Out:
# brands
# toyota         32
# nissan         18
# mazda          17
# mitsubishi     13
# honda          13
# volkswagen     12
# subaru         12
# peugeot        11
# volvo          11
# dodge           9
# buick           8
# bmw             8
# audi            7
# plymouth        7
# saab            6
# porsche         5
# isuzu           4
# jaguar          3
# chevrolet       3
# alfa-romero     3
# renault         2
# mercury         1
# Name: count, dtype: int64

# %%
sns.countplot(x=df["brands"], palette='pastel')
plt.tight_layout()
plt.xticks(rotation=90)
plt.show()

# %%
df.drop("car_ID", axis = 1, inplace = True)
df
# Out:
#      symboling                   CarName fueltype aspiration doornumber  \
# 0            3        alfa-romero giulia      gas        std        two
# 1            3       alfa-romero stelvio      gas        std        two
# 2            1  alfa-romero Quadrifoglio      gas        std        two
# 3            2               audi 100 ls      gas        std       four
# 4            2                audi 100ls      gas        std       four
# ..         ...                       ...      ...        ...        ...
# 200         -1           volvo 145e (sw)      gas        std       four
# 201         -1               volvo 144ea      gas      turbo       four
# 202         -1               volvo 244dl      gas        std       four
# 203         -1                 volvo 246   diesel      turbo       four
# 204         -1               volvo 264gl      gas      turbo       four
#
#          carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# ...

# %%
df[df["enginelocation"] == 'rear']
# Out:
#      symboling            CarName fueltype aspiration doornumber      carbody  \
# 126          3  porcshce panamera      gas        std        two      hardtop
# 127          3    porsche cayenne      gas        std        two      hardtop
# 128          3     porsche boxter      gas        std        two  convertible
#
#     drivewheel enginelocation  wheelbase  carlength  ...  fuelsystem  \
# 126        rwd           rear       89.5      168.9  ...        mpfi
# 127        rwd           rear       89.5      168.9  ...        mpfi
# 128        rwd           rear       89.5      168.9  ...        mpfi
#
#      boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 126       3.74     2.9              9.5        207     5900      17
# 127       3.74     2.9              9.5        207     5900      17
# 128       3.74     2.9              9.5        207     5900      17
#
#      highwaympg    price   brands
# 126          25  32528.0  porsche
# ...

# %%
df[df["cylindernumber"] != 'four']
# Out:
#      symboling                          CarName fueltype aspiration  \
# 2            1         alfa-romero Quadrifoglio      gas        std
# 4            2                       audi 100ls      gas        std
# 5            2                         audi fox      gas        std
# 6            1                       audi 100ls      gas        std
# 7            1                        audi 5000      gas        std
# 8            1                        audi 4000      gas      turbo
# 9            0              audi 5000s (diesel)      gas      turbo
# 12           0                           bmw x1      gas        std
# 13           0                           bmw x3      gas        std
# 14           1                           bmw z4      gas        std
# 15           0                           bmw x4      gas        std
# 16           0                           bmw x5      gas        std
# 17           0                           bmw x3      gas        std
# ...

# %%
categories = ['fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber', 'fuelsystem']

plt.figure(figsize = (20,10))
for feature in categories:
    
    plt.subplot(3, 3, categories.index(feature) + 1)
    sns.boxplot(data=df, x=feature, y='price')
    plt.title(f'{feature} vs. Price')
plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for feature in categories:
    df[feature] = le.fit_transform(df[feature])
    
df
# Out:
#      symboling                   CarName  fueltype  aspiration  doornumber  \
# 0            3        alfa-romero giulia         1           0           1
# 1            3       alfa-romero stelvio         1           0           1
# 2            1  alfa-romero Quadrifoglio         1           0           1
# 3            2               audi 100 ls         1           0           0
# 4            2                audi 100ls         1           0           0
# ..         ...                       ...       ...         ...         ...
# 200         -1           volvo 145e (sw)         1           0           0
# 201         -1               volvo 144ea         1           1           0
# 202         -1               volvo 244dl         1           0           0
# 203         -1                 volvo 246         0           1           0
# 204         -1               volvo 264gl         1           1           0
#
# ...

# %%
df_new = df.drop(["CarName", "brands"], axis = 1)
df_new
# Out:
#      symboling  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0            3         1           0           1        0           2
# 1            3         1           0           1        0           2
# 2            1         1           0           1        2           2
# 3            2         1           0           0        3           1
# 4            2         1           0           0        3           0
# ..         ...       ...         ...         ...      ...         ...
# 200         -1         1           0           0        3           2
# 201         -1         1           1           0        3           2
# 202         -1         1           0           0        3           2
# 203         -1         0           1           0        3           2
# 204         -1         1           1           0        3           2
#
#      enginelocation  wheelbase  carlength  carwidth  ...  enginesize  \
# ...

# %%
plt.figure(figsize=(25,25))
sns.heatmap(df_new.corr(),annot=True,cmap="mako")
plt.show()

# %% [markdown]
# <h1> enginesize, carlength, cityhighway, drivewheel, wheelbase<h1>

# %%
df_new["cityhighwaympg"] = df_new["citympg"] + df_new["highwaympg"]

# %%
df_new.drop(["citympg", "highwaympg"], axis = 1, inplace = True)
df_new
# Out:
#      symboling  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0            3         1           0           1        0           2
# 1            3         1           0           1        0           2
# 2            1         1           0           1        2           2
# 3            2         1           0           0        3           1
# 4            2         1           0           0        3           0
# ..         ...       ...         ...         ...      ...         ...
# 200         -1         1           0           0        3           2
# 201         -1         1           1           0        3           2
# 202         -1         1           0           0        3           2
# 203         -1         0           1           0        3           2
# 204         -1         1           1           0        3           2
#
#      enginelocation  wheelbase  carlength  carwidth  ...  cylindernumber  \
# ...

# %%
df_new.drop(["curbweight", "horsepower"], axis = 1, inplace = True)

# %%
df_new2 = df_new[["enginesize", "carlength", "cityhighwaympg", "drivewheel", "wheelbase", "price"]]
df_new2
# Out:
#      enginesize  carlength  cityhighwaympg  drivewheel  wheelbase    price
# 0           130      168.8              48           2       88.6  13495.0
# 1           130      168.8              48           2       88.6  16500.0
# 2           152      171.2              45           2       94.5  16500.0
# 3           109      176.6              54           1       99.8  13950.0
# 4           136      176.6              40           0       99.4  17450.0
# ..          ...        ...             ...         ...        ...      ...
# 200         141      188.8              51           2      109.1  16845.0
# 201         141      188.8              44           2      109.1  19045.0
# 202         173      188.8              41           2      109.1  21485.0
# 203         145      188.8              53           2      109.1  22470.0
# 204         141      188.8              44           2      109.1  22625.0
#
# [205 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
X = df_new.drop('price',axis = 1 )
y = df_new['price']
X_train,X_test,y_train,y_test =  train_test_split(X,y,train_size = 0.80 , random_state = 42)
X_train
# Out:
#      symboling  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 66           0         0           0           0        3           2
# 111          0         1           0           0        3           2
# 153          0         1           0           0        4           1
# 96           1         1           0           0        3           1
# 38           0         1           0           1        2           1
# ..         ...       ...         ...         ...      ...         ...
# 106          1         1           0           1        2           2
# 14           1         1           0           0        3           2
# 92           1         1           0           0        3           1
# 179          3         1           0           1        2           2
# 102          0         1           0           0        4           1
#
#      enginelocation  wheelbase  carlength  carwidth  carheight  enginetype  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import Ridge

mmc = MinMaxScaler()

X_train = mmc.fit_transform(X_train)
X_test = mmc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=1000, random_state=1, max_depth = 5)
model = rf.fit(X_train,y_train)
model.score(X_test,y_test)
#model.score(X_train,y_train)
# Out:
# 0.9443408867630135

# %%
y_pred = rf.predict(X_test)
mean_absolute_error(y_test, y_pred)
# Out:
# 1551.988603482029

# %%
import tensorflow as tf
from tensorflow import keras

# %%
normalizer = tf.keras.layers.Normalization()
normalizer.adapt(np.array(X_train))

# %%
input_shape = (X_train.shape[1],)
model = tf.keras.Sequential([
    normalizer,
    tf.keras.layers.Dense(units=300, activation='relu',
                          input_shape=input_shape),
    tf.keras.layers.Dense(units=200, activation='relu'),
    tf.keras.layers.Dropout(
        0.2
    ),
    tf.keras.layers.Dense(units=200, activation='relu'),
    #tf.keras.layers.Dense(units=64, activation='relu'),
    #tf.keras.layers.Dense(units=128, activation='relu'),
    tf.keras.layers.Dense(units=1)
])

# %%
optimizer=tf.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer, loss='mse', metrics = "mae")

# %%
loss=model.fit(X_train, y_train, epochs = 500, validation_data = (X_test, y_test))
# Out:
# Epoch 1/500
# 6/6 [==============================] - 1s 38ms/step - loss: 234470896.0000 - mae: 13222.5674 - val_loss: 260842240.0000 - val_mae: 13487.2041
# Epoch 2/500
# 6/6 [==============================] - 0s 7ms/step - loss: 234378016.0000 - mae: 13219.2852 - val_loss: 260680560.0000 - val_mae: 13481.8213
# Epoch 3/500
# 6/6 [==============================] - 0s 7ms/step - loss: 234143424.0000 - mae: 13211.8486 - val_loss: 260313344.0000 - val_mae: 13469.8857
# Epoch 4/500
# 6/6 [==============================] - 0s 7ms/step - loss: 233672304.0000 - mae: 13196.2441 - val_loss: 259556928.0000 - val_mae: 13445.8779
# Epoch 5/500
# 6/6 [==============================] - 0s 7ms/step - loss: 232754208.0000 - mae: 13166.4980 - val_loss: 258135040.0000 - val_mae: 13402.1055
# Epoch 6/500
# 6/6 [==============================] - 0s 8ms/step - loss: 231066576.0000 - mae: 13112.9756 - val_loss: 255686432.0000 - val_mae: 13328.6953
# Epoch 7/500
# ...

# %%
loss_df = pd.DataFrame(loss.history)

loss_df.loc[:,['loss']].plot()
# Out:
# <Axes: >

# %%
loss_df.loc[:,['val_loss']].plot()
# Out:
# <Axes: >

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error

# %%
gb = GradientBoostingRegressor()
gb.fit(X_train, y_train)
gb.score(X_test, y_test)
# Out:
# 0.9314875581836983

# %%
gb = GradientBoostingRegressor(loss = 'absolute_error')
gb.fit(X_train, y_train)
gb.score(X_test, y_test)
# Out:
# 0.9246506209600114

# %%
y_pred = gb.predict(X_test)
mean_absolute_error(y_test, y_pred)
# Out:
# 1695.6668000418379

# %%
from sklearn.model_selection import train_test_split
X = df_new2.drop('price',axis = 1 )
y = df_new2['price']
X_train,X_test,y_train,y_test =  train_test_split(X,y,train_size = 0.80 , random_state = 42)
X_train
# Out:
#      enginesize  carlength  cityhighwaympg  drivewheel  wheelbase
# 66          134      175.0              70           2      104.9
# 111         120      186.7              43           2      107.9
# 153          92      169.7              68           1       95.7
# 96           97      165.3              68           1       94.5
# 38          110      167.5              60           1       96.5
# ..          ...        ...             ...         ...        ...
# 106         181      178.5              44           2       99.2
# 14          164      189.0              45           2      103.5
# 92           97      165.3              68           1       94.5
# 179         171      183.5              43           2      102.9
# 102         181      184.6              39           1      100.4
#
# [164 rows x 5 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import Ridge

mmc = MinMaxScaler()

X_train = mmc.fit_transform(X_train)
X_test = mmc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=1000, random_state=1, max_depth = 5)
model = rf.fit(X_train,y_train)
model.score(X_test,y_test)
#model.score(X_train,y_train)
# Out:
# 0.9434905128042239

# %%
y_pred = rf.predict(X_test)
mean_absolute_error(y_test, y_pred)
# Out:
# 1543.8253917272623

# %%
normalizer = tf.keras.layers.Normalization()
normalizer.adapt(np.array(X_train))

# %%
input_shape = (X_train.shape[1],)
model = tf.keras.Sequential([
    normalizer,
    tf.keras.layers.Dense(units=300, activation='relu',
                          input_shape=input_shape),
    tf.keras.layers.Dense(units=200, activation='relu'),
    tf.keras.layers.Dropout(
        0.2
    ),
    tf.keras.layers.Dense(units=200, activation='relu'),
    #tf.keras.layers.Dense(units=64, activation='relu'),
    #tf.keras.layers.Dense(units=128, activation='relu'),
    tf.keras.layers.Dense(units=1)
])

# %%
optimizer=tf.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer, loss='mse', metrics = "mae")

# %%
loss=model.fit(X_train, y_train, epochs = 500, validation_data = (X_test, y_test))
# Out:
# Epoch 1/500
# 6/6 [==============================] - 1s 43ms/step - loss: 234483936.0000 - mae: 13222.9590 - val_loss: 260873936.0000 - val_mae: 13488.2744
# Epoch 2/500
# 6/6 [==============================] - 0s 8ms/step - loss: 234431488.0000 - mae: 13221.0820 - val_loss: 260774144.0000 - val_mae: 13484.8838
# Epoch 3/500
# 6/6 [==============================] - 0s 6ms/step - loss: 234309760.0000 - mae: 13216.9131 - val_loss: 260559920.0000 - val_mae: 13477.7285
# Epoch 4/500
# 6/6 [==============================] - 0s 7ms/step - loss: 234074112.0000 - mae: 13208.6758 - val_loss: 260135136.0000 - val_mae: 13463.9209
# Epoch 5/500
# 6/6 [==============================] - 0s 6ms/step - loss: 233624848.0000 - mae: 13192.9219 - val_loss: 259357888.0000 - val_mae: 13439.0684
# Epoch 6/500
# 6/6 [==============================] - 0s 7ms/step - loss: 232777152.0000 - mae: 13165.1328 - val_loss: 258014832.0000 - val_mae: 13396.3799
# Epoch 7/500
# ...

# %%
def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.xlabel('Epoch')
  plt.ylabel('Error')
  plt.legend()


plot_loss(loss)
